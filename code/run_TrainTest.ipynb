# %% [markdown]
# ## Train and test a classifier for each of the feature sets  for each dataset

# %%
# %reload_ext autoreload
# %autoreload 2
import os
import pandas as pd
import pickle
import random
import numpy as np
import csv
import timeit
from collections import defaultdict, Counter
from pathlib import Path
from Bio import SeqIO
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split 
from sklearn.metrics import roc_auc_score
import sys
lib_dir = '../mylibs'
if lib_dir not in sys.path:
    sys.path.append(lib_dir)
# %matplotlib inline    
    
import vhdb as vhdb
from featureset import FeatureSet
from dataset import DataSet

# %%
def get_confusion( y_test,y_pred):
    FN=0
    FP=0
    TP=0
    TN=0
    #missed = 0
    for y,yp in zip(y_test,y_pred):
        #print (y_true,yp,yp2,yprob)
        if y == True and yp == False:
            FN += 1
        elif y == False and yp == True:
            FP +=1
        elif y == True and yp == True:
            TP +=1
        else:
            TN +=1
    spec = round(TN/(TN+FP),2) if (TN + TP) else 'NA'
    sens = round(TP/(TP+FN),2) if (TP+FN) else 'NA'
    fdr  = round(FP/(TP+FP),2) if (TP+FP) else 'NA'
    res  = { 'Acc':round((TP+TN)/(len(y_test)),2),'Spec':spec, 'Sens':sens,\
           'prec':fdr,'TP':TP, 'TN':TN, 'FP':FP, 'FN':FN}
    return res


def test_prediction(fs,y_trn,y_tst):
    clf = make_pipeline(StandardScaler(),SVC(kernel='linear',probability=True) )
    clf.fit(fs.X_trn, y_trn)
    y_pred = clf.predict(fs.X_tst)
    y_pred_probs= clf.predict_proba(fs.X_tst)[:,1]
    AUC =round( roc_auc_score(y_tst, y_pred_probs),3)  
    confusion = get_confusion(y_tst,y_pred)
    confusion.update({'AUC':AUC})
    return confusion

# %% [markdown]
# ### The input dataset files in ../inputs
# 1. Bacteria_DNA.csv
# 2. Euk_subsets.csv
# 3. Euk_all.csv
# 4. Euk_RNA.csv

# %% [markdown]
# ### Load the input files to train and test
# 1. input/ datasets
# 2. VHDB

# %%
# Input file  
subsetfile = '../inputs/Bacteria_DNA.csv'
label_info = pd.read_csv(subsetfile)
subsets = label_info.apply(tuple, axis=1).tolist()
print(f'{len(subsets)} datasets : {subsets[0]}')
for s in subsets:
    print(s)
vhdbfile = '../inputs/VHDB_25_1_2019.p'
with open(vhdbfile, 'rb') as f:
    V_H = pickle.load( f)
hosts = V_H.hosts
viruses = V_H.viruses
print (f'{len(viruses)} viruses and {len(hosts)} hosts')


# Output file for the results
results_file = f'../results/{Path(subsetfile).stem}_results.csv '
print (f'Results will be saved in: {results_file}')
# Out:
# 67 datasets : ('Alteromonadales', 'order', 'Gammaproteobacteria', 'class', 'DNA')
# ('Alteromonadales', 'order', 'Gammaproteobacteria', 'class', 'DNA')
# ('Salmonella enterica', 'species', 'Enterobacteriaceae', 'family', 'DNA')
# ('Salmonella', 'genus', 'Enterobacteriaceae', 'family', 'DNA')
# ('Escherichia coli', 'species', 'Enterobacteriaceae', 'family', 'DNA')
# ('Escherichia', 'genus', 'Enterobacteriaceae', 'family', 'DNA')
# ('Klebsiella pneumoniae', 'species', 'Enterobacteriaceae', 'family', 'DNA')
# ('Klebsiella', 'genus', 'Enterobacteriaceae', 'family', 'DNA')
# ('Enterobacteriaceae', 'family', 'Enterobacterales', 'order', 'DNA')
# ('Erwiniaceae', 'family', 'Enterobacterales', 'order', 'DNA')
# ('Enterobacterales', 'order', 'Gammaproteobacteria', 'class', 'DNA')
# ('Acinetobacter', 'genus', 'Pseudomonadales', 'order', 'DNA')
# ('Moraxellaceae', 'family', 'Pseudomonadales', 'order', 'DNA')
# ('Pseudomonas', 'genus', 'Pseudomonadales', 'order', 'DNA')
# ('Pseudomonadales', 'order', 'Gammaproteobacteria', 'class', 'DNA')
# ('Vibrio cholerae', 'species', 'Vibrio', 'genus', 'DNA')
# ('Vibrio', 'genus', 'Gammaproteobacteria', 'class', 'DNA')
# ('Vibrionaceae', 'family', 'Gammaproteobacteria', 'class', 'DNA')
# ('Gammaproteobacteria', 'class', 'Proteobacteria', 'phylum', 'DNA')
# ('Burkholderia', 'genus', 'Burkholderiales', 'order', 'DNA')
# ('Burkholderiaceae', 'family', 'Proteobacteria', 'phylum', 'DNA')
# ('Burkholderiales', 'order', 'Proteobacteria', 'phylum', 'DNA')
# ('Betaproteobacteria', 'class', 'Proteobacteria', 'phylum', 'DNA')
# ('Rhizobiales', 'order', 'Alphaproteobacteria', 'class', 'DNA')
# ('Alphaproteobacteria', 'class', 'Proteobacteria', 'phylum', 'DNA')
# ('Proteobacteria', 'phylum', 'Bacteria', 'superkingdom', 'DNA')
# ('Bacillus thuringiensis', 'species', 'Bacillus', 'genus', 'DNA')
# ('Bacillus cereus', 'species', 'Bacillus', 'genus', 'DNA')
# ('Bacillus', 'genus', 'Bacillales', 'order', 'DNA')
# ('Bacillaceae', 'family', 'Bacillales', 'order', 'DNA')
# ('Listeria monocytogenes', 'species', 'Bacillales', 'order', 'DNA')
# ('Listeria', 'genus', 'Bacillales', 'order', 'DNA')
# ('Listeriaceae', 'family', 'Bacillales', 'order', 'DNA')
# ('Staphylococcus aureus', 'species', 'Bacillales', 'order', 'DNA')
# ('Staphylococcus', 'genus', 'Bacillales', 'order', 'DNA')
# ('Bacillales', 'order', 'Bacilli', 'class', 'DNA')
# ('Lactobacillus', 'genus', 'Lactobacillales', 'order', 'DNA')
# ('Lactobacillaceae', 'family', 'Lactobacillales', 'order', 'DNA')
# ('Streptococcus', 'genus', 'Streptococcaceae', 'family', 'DNA')
# ('Lactococcus lactis', 'species', 'Streptococcaceae', 'family', 'DNA')
# ('Lactococcus', 'genus', 'Streptococcaceae', 'family', 'DNA')
# ('Streptococcaceae', 'family', 'Lactobacillales', 'order', 'DNA')
# ('Enterococcus faecalis', 'species', 'Lactobacillales', 'order', 'DNA')
# ('Enterococcus', 'genus', 'Lactobacillales', 'order', 'DNA')
# ('Lactobacillales', 'order', 'Bacilli', 'class', 'DNA')
# ('Bacilli', 'class', 'Firmicutes', 'phylum', 'DNA')
# ('Clostridium', 'genus', 'Firmicutes', 'phylum', 'DNA')
# ('Clostridiales', 'order', 'Firmicutes', 'phylum', 'DNA')
# ('Clostridia', 'class', 'Firmicutes', 'phylum', 'DNA')
# ('Firmicutes', 'phylum', 'Bacteria', 'superkingdom', 'DNA')
# ('Mycolicibacterium smegmatis', 'species', 'Corynebacteriales', 'order', 'DNA')
# ('Mycolicibacterium', 'genus', 'Corynebacteriales', 'order', 'DNA')
# ('Mycobacterium', 'genus', 'Mycobacteriaceae', 'family', 'DNA')
# ('Mycobacteriaceae', 'family', 'Corynebacteriales', 'order', 'DNA')
# ('Gordonia terrae', 'species', 'Corynebacteriales', 'order', 'DNA')
# ('Gordonia', 'genus', 'Corynebacteriales', 'order', 'DNA')
# ('Corynebacteriales', 'order', 'Actinobacteria', 'class', 'DNA')
# ('Propionibacterium', 'genus', 'Actinobacteria', 'class', 'DNA')
# ('Cutibacterium acnes', 'species', 'Actinobacteria', 'class', 'DNA')
# ('Propionibacteriaceae', 'family', 'Actinobacteria', 'class', 'DNA')
# ('Actinobacteria', 'phylum', 'Bacteria', 'superkingdom', 'DNA')
# ('Prochlorococcus', 'genus', 'Synechococcales', 'order', 'DNA')
# ('Synechococcus sp. WH 7803', 'species', 'Synechococcus', 'genus', 'DNA')
# ('Synechococcales', 'order', 'Bacteria', 'superkingdom', 'DNA')
# ('Cyanobacteria', 'phylum', 'Bacteria', 'superkingdom', 'DNA')
# ('Cellulophaga', 'genus', 'Bacteria', 'superkingdom', 'DNA')
# ('Flavobacteriaceae', 'family', 'Bacteria', 'superkingdom', 'DNA')
# ('Bacteroidetes', 'phylum', 'Bacteria', 'superkingdom', 'DNA')
# 9199 viruses and 3006 hosts
# Results will be saved in: ../results/Bacteria_DNA_results.csv

# %%
features = ['DNA','AA','PC','Domains']
kmer_lists = [[1,2,3,4,5,6,7,8,9], # dna 
              [1,2,3,4],           # aa
              [1,2,3,4,5,6] ,      #pc
              [0]]  
feature_sets = [f'{f}_{k}' for i,f in enumerate(features) for k in kmer_lists[i] ]

# %%
all_results =[]
for subset in subsets:
    print  (subset)
    data = DataSet(subset,V_H,feature_sets=feature_sets)
    (label,label_tax,pool,pool_tax,baltimore) = subset
    print  (label,label_tax,pool,pool_tax,baltimore)
    print((data.ds.groupby(['y','trn/tst']).count(),'\n'))
    mask = data.ds['trn/tst']=='train'
    y_train = np.asarray(data.ds[mask]['y'],dtype=int)
    y_test = np.asarray(data.ds[~mask
                               ]['y'],dtype=int)
    for fs in data.fs:
        results = test_prediction(fs,y_train,y_test)
        results.update ({'N': len(data.ds), 'features':fs.feature, 'k':fs.k})
        print(results)
        data.results2CSV (results,subset, results_file)
        all_results.append(results)
    results_df = pd.DataFrame(all_results)
# Out:
# ('Alteromonadales', 'order', 'Gammaproteobacteria', 'class', 'DNA')
# missing 7
# train test split 39 14
#      virus  y      refseqs trn/tst
# 0  1458862  1  [NC_025463]    test
# 1  1667322  1  [NC_029100]   train
# 2  1458861  1  [NC_025458]   train
# 3  1527515  1  [NC_025471]    test
# 4    10661  1  [NC_000867]   train
# Adding feature sets  ['DNA_1', 'DNA_2', 'DNA_3', 'DNA_4', 'DNA_5', 'DNA_6', 'DNA_7', 'DNA_8', 'DNA_9', 'AA_1', 'AA_2', 'AA_3', 'AA_4', 'PC_1', 'PC_2', 'PC_3', 'PC_4', 'PC_5', 'PC_6', 'Domains_0']
# adding fs DNA_1
# FS get sequences for length ds 53
# FS get feature names DNA_1 53
# FS get X len fs 4
# 53 53 4 (53, 4)
# /home4/youn01f/Desktop/workspace/virus_host_predict/code/dataset.py:230: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['trn/tst'] = train.apply(lambda row: 'train', axis = 1)
# /home4/youn01f/Desktop/workspace/virus_host_predict/code/dataset.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['trn/tst'] = test.apply(lambda row: 'test', axis = 1)
# adding fs DNA_2
# FS get sequences for length ds 53
# FS get feature names DNA_2 53
# FS get X len fs 16
# 53 53 16 (53, 16)
# adding fs DNA_3
# FS get sequences for length ds 53
# FS get feature names DNA_3 53
# FS get X len fs 64
# 53 53 64 (53, 64)
# adding fs DNA_4
# FS get sequences for length ds 53
# FS get feature names DNA_4 53
# FS get X len fs 256
# 53 53 256 (53, 256)
# adding fs DNA_5
# FS get sequences for length ds 53
# FS get feature names DNA_5 53
# FS get X len fs 1024
# 53 53 1024 (53, 1024)
# adding fs DNA_6
# FS get sequences for length ds 53
# FS get feature names DNA_6 53
# FS get X len fs 4096
# 53 53 4096 (53, 4096)
# adding fs DNA_7
# FS get sequences for length ds 53
# FS get feature names DNA_7 53
# FS get X len fs 16384
# 53 53 16384 (53, 16384)
# adding fs DNA_8
# FS get sequences for length ds 53
# FS get feature names DNA_8 53
# FS get X len fs 65536
# 53 53 65536 (53, 65536)
# adding fs DNA_9
# FS get sequences for length ds 53
# FS get feature names DNA_9 53
# FS get X len fs 262144
# 53 53 262144 (53, 262144)
