# %% [markdown]
# ### Run Holdout classification on bacteria datasets with ANI filter.
# The holdout datasets are created  using a different function (dataset.ho_get_class_list) . This includes removing viruses with closer than 75%ANI with any holdout(test) viruses from the training data.

# %%
# %reload_ext autoreload
# %autoreload 2
import os
import pandas as pd
import pickle
import random
import numpy as np
import pandas as pd
from collections import defaultdict, Counter
import csv
from pathlib import Path
import sys

from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split 
from sklearn.metrics import roc_auc_score

lib_dir = '../mylibs'
if lib_dir not in sys.path:
    sys.path.append(lib_dir)
    
import vhdb as vhdb
from featureset import FeatureSet
from dataset import DataSet

# %% [markdown]
# #### Load the input file containing datasets to be trained/tested and load the VHDB

# %%
# Input file  
subsetfile = 'inputs/Bact_holdout.csv'
label_info = pd.read_csv(subsetfile)
subsets = label_info.apply(tuple, axis=1).tolist()
print(f'{len(subsets)} datasets : {subsets[0]}')

vhdbfile = '../inputs/VHDB_25_1_2019.p'
with open(vhdbfile, 'rb') as f:
    V_H = pickle.load( f)
hosts = V_H.hosts
viruses = V_H.viruses
print (f'{len(viruses)} viruses and {len(hosts)} hosts')


# Output file for the results
out_file = Path(subsetfile).stem 
results_file = 'results/test_ANI_holdout_results.csv'
print (f'Results will be saved in: {results_file}')
# Out:
# 24 datasets : ('Bacteroidetes', 'phylum', 'Bacteria', 'kingdom', 'DNA', 'Siphoviridae')
# 9199 viruses and 3006 hosts
# Results will be saved in: results/test_ANI_holdout_results.csv

# %%
def get_confusion( y_test,y_pred):
    FN=0
    FP=0
    TP=0
    TN=0
    #missed = 0
    for y,yp in zip(y_test,y_pred):
        #print (y_true,yp,yp2,yprob)
        if y == True and yp == False:
            FN += 1
        elif y == False and yp == True:
            FP +=1
        elif y == True and yp == True:
            TP +=1
        else:
            TN +=1
   
    spec = round(TN/(TN+FP),2) if (TN + TP) else 'NA'
    sens = round(TP/(TP+FN),2) if (TP+FN) else 'NA'
    prec  = round(TP/(TP+FP),2) if (TP+FP) else 'NA'
    res  = { 'Acc':round((TP+TN)/(len(y_test)),2),'Spec':spec, 'Sens':sens,\
           'Prec':prec}
    return res

def test_prediction(fs,y_trn,y_tst):
    clf = make_pipeline(StandardScaler(),svm.SVC(kernel='linear',probability=True) )
    clf.fit(fs.X_trn, y_trn)
    y_pred = clf.predict(fs.X_tst)
    y_pred_probs= clf.predict_proba(fs.X_tst)[:,1]
    AUC =round( roc_auc_score(y_tst, y_pred_probs),3)
    results = {'AUC':AUC, 'features':fs.feature,'k':fs.k}
    confusion = get_confusion(y_tst,y_pred)
    results.update(confusion)
    return results

# %% [markdown]
# ### Set up the different features to be tested and corresponding lists:
# 1. Filepaths and extensions
# 2. k-mer lengths
# 3. Lookup for symbols used in sequences

# %%
features = ['DNA','AA','PC','Domains']
kmer_lists = [[2,6,9], # dna 
              [3,4],           # aa
              [5,6] ,      #pc
              [0]]  
feature_sets = [f'{f}_{k}' for i,f in enumerate(features) for k in kmer_lists[i] ]
#feature_sets = ['DNA_2', 'AA_2', 'PC_2', 'Domains_0'] #test
feature_sets
# Out:
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0']

# %%
len(subsets)
# Out:
# 24

# %% [markdown]
# ## Main loop
# #### For each dataset, run inner loop to train and test  all feature sets  as holdout classifiers.

# %%
#[ho_pos, ho_neg,not_ho_pos,not_ho_neg]

for subset in subsets[12:20]:
    print('*****',subset)
#     # for holdout data  
    holdout = subset[-1]
    subset = subset [:-1]
    print ( holdout, subset)
    data = DataSet(subset,V_H,feature_sets= [],tt_split = 0, holdout=holdout)
    
    all_results =[]
    
    mask = data.ds['trn/tst']=='train'
    y_train = np.asarray(data.ds[mask]['y'],dtype=int)
    if len(y_train) > 40:
        print ('OK*************', len(y_train))
        data.addFeatureSets(feature_sets)
        y_test = np.asarray(data.ds[~mask]['y'],dtype=int)
        for fs in data.fs:
            results = test_prediction(fs,y_train,y_test)
            data.results2CSV (results,subset, results_file)
            all_results.append(results)
results_df = pd.DataFrame(all_results)
# Out:
# ***** ('Bacillales', 'order', 'Firmicutes', 'phylum', 'DNA', 'Podoviridae')
# Podoviridae ('Bacillales', 'order', 'Firmicutes', 'phylum', 'DNA')
# before ani -not_ho pos 296 neg 305
# after ani -not_ho pos 286 neg 261
# Bacillales_Podoviridae [296, 305, 286, 261]
# ho_pos 17 ho_neg 17 not_ho_pos 200 not_ho_neg 200
# holdout  Podoviridae 434
#      virus  y      refseqs trn/tst
# 0    10778  1  [NC_004165]    test
# 1  1675598  1  [NC_028782]    test
# 2   204090  1  [NC_004679]    test
# 3  1010614  1  [NC_016565]    test
# 4  1597966  1  [NC_028926]    test
# OK************* 399
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0'] <class 'list'>
# adding fs DNA_2
# DNA_2 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names DNA_2 432
# FS get X len fs 16
# 432 432 16 (432, 16)
# adding fs DNA_6
# DNA_6 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names DNA_6 432
# FS get X len fs 4096
# 432 432 4096 (432, 4096)
# adding fs DNA_9
# DNA_9 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names DNA_9 432
# FS get X len fs 262144
# 432 432 262144 (432, 262144)
# adding fs AA_3
# AA_3 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names AA_3 432
# FS get X len fs 8000
# 432 432 8000 (432, 8000)
# adding fs AA_4
# AA_4 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names AA_4 432
# FS get X len fs 160000
# 432 432 160000 (432, 160000)
# adding fs PC_5
# PC_5 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names PC_5 432
# FS get X len fs 16807
# 432 432 16807 (432, 16807)
# adding fs PC_6
# PC_6 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names PC_6 432
# FS get X len fs 117649
# 432 432 117649 (432, 117649)
# adding fs Domains_0
# Domains_0 <class 'str'>
# FS get sequences for length ds 432
# FS get feature names Domains_0 432
# FS get X len fs 911
# 432 432 911 (432, 911)
# {'AUC': 0.607, 'features': 'DNA', 'k': 2, 'Acc': 0.64, 'Spec': 0.53, 'Sens': 0.75, 'Prec': 0.6, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.949, 'features': 'DNA', 'k': 6, 'Acc': 0.82, 'Spec': 0.65, 'Sens': 1.0, 'Prec': 0.73, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.952, 'features': 'DNA', 'k': 9, 'Acc': 0.82, 'Spec': 0.65, 'Sens': 1.0, 'Prec': 0.73, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.835, 'features': 'AA', 'k': 3, 'Acc': 0.73, 'Spec': 0.59, 'Sens': 0.88, 'Prec': 0.67, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.673, 'features': 'AA', 'k': 4, 'Acc': 0.64, 'Spec': 0.29, 'Sens': 1.0, 'Prec': 0.57, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.838, 'features': 'PC', 'k': 5, 'Acc': 0.73, 'Spec': 0.88, 'Sens': 0.56, 'Prec': 0.82, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.757, 'features': 'PC', 'k': 6, 'Acc': 0.64, 'Spec': 0.29, 'Sens': 1.0, 'Prec': 0.57, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# {'AUC': 0.816, 'features': 'Domains', 'k': 0, 'Acc': 0.64, 'Spec': 0.71, 'Sens': 0.56, 'Prec': 0.64, 'label': 'Bacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 432}
# ***** ('Lactobacillales', 'order', 'Firmicutes', 'phylum', 'DNA', 'Siphoviridae')
# Siphoviridae ('Lactobacillales', 'order', 'Firmicutes', 'phylum', 'DNA')
# before ani -not_ho pos 32 neg 175
# after ani -not_ho pos 21 neg 157
# Lactobacillales_Siphoviridae [32, 175, 21, 157]
# ho_pos 20 ho_neg 20 not_ho_pos 21 not_ho_neg 21
# holdout  Siphoviridae 82
#      virus  y      refseqs trn/tst
# 0   139870  1  [NC_005355]    test
# 1  1871681  1  [NC_031040]    test
# 2  1566990  1  [NC_027396]    test
# 3   947981  1  [NC_019489]    test
# 4    31754  1  [NC_002796]    test
# OK************* 41
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0'] <class 'list'>
# adding fs DNA_2
# DNA_2 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names DNA_2 81
# FS get X len fs 16
# 81 81 16 (81, 16)
# adding fs DNA_6
# DNA_6 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names DNA_6 81
# FS get X len fs 4096
# 81 81 4096 (81, 4096)
# adding fs DNA_9
# DNA_9 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names DNA_9 81
# FS get X len fs 262144
# 81 81 262144 (81, 262144)
# adding fs AA_3
# AA_3 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names AA_3 81
# FS get X len fs 8000
# 81 81 8000 (81, 8000)
# adding fs AA_4
# AA_4 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names AA_4 81
# FS get X len fs 160000
# 81 81 160000 (81, 160000)
# adding fs PC_5
# PC_5 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names PC_5 81
# FS get X len fs 16807
# 81 81 16807 (81, 16807)
# adding fs PC_6
# PC_6 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names PC_6 81
# FS get X len fs 117649
# 81 81 117649 (81, 117649)
# adding fs Domains_0
# Domains_0 <class 'str'>
# FS get sequences for length ds 81
# FS get feature names Domains_0 81
# FS get X len fs 527
# 81 81 527 (81, 527)
# {'AUC': 0.812, 'features': 'DNA', 'k': 2, 'Acc': 0.7, 'Spec': 0.45, 'Sens': 0.95, 'Prec': 0.63, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.982, 'features': 'DNA', 'k': 6, 'Acc': 0.85, 'Spec': 0.7, 'Sens': 1.0, 'Prec': 0.77, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.925, 'features': 'DNA', 'k': 9, 'Acc': 0.8, 'Spec': 1.0, 'Sens': 0.6, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.948, 'features': 'AA', 'k': 3, 'Acc': 0.8, 'Spec': 1.0, 'Sens': 0.6, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.94, 'features': 'AA', 'k': 4, 'Acc': 0.5, 'Spec': 1.0, 'Sens': 0.0, 'Prec': 'NA', 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.891, 'features': 'PC', 'k': 5, 'Acc': 0.72, 'Spec': 1.0, 'Sens': 0.45, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.935, 'features': 'PC', 'k': 6, 'Acc': 0.55, 'Spec': 1.0, 'Sens': 0.1, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# {'AUC': 0.835, 'features': 'Domains', 'k': 0, 'Acc': 0.82, 'Spec': 1.0, 'Sens': 0.65, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 81}
# ***** ('Lactobacillales', 'order', 'Firmicutes', 'phylum', 'DNA', 'Myoviridae')
# Myoviridae ('Lactobacillales', 'order', 'Firmicutes', 'phylum', 'DNA')
# before ani -not_ho pos 261 neg 234
# after ani -not_ho pos 215 neg 213
# Lactobacillales_Myoviridae [261, 234, 215, 213]
# ho_pos 14 ho_neg 14 not_ho_pos 200 not_ho_neg 200
# holdout  Myoviridae 428
#      virus  y      refseqs trn/tst
# 1  1206110  1  [NC_019782]    test
# 2   755164  1  [NC_027990]    test
# 3   139871  1  [NC_010179]    test
# 4   632112  1  [NC_012530]    test
# 5  1416334  1  [NC_024206]    test
# OK************* 398
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0'] <class 'list'>
# adding fs DNA_2
# DNA_2 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names DNA_2 425
# FS get X len fs 16
# 425 425 16 (425, 16)
# adding fs DNA_6
# DNA_6 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names DNA_6 425
# FS get X len fs 4096
# 425 425 4096 (425, 4096)
# adding fs DNA_9
# DNA_9 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names DNA_9 425
# FS get X len fs 262144
# 425 425 262144 (425, 262144)
# adding fs AA_3
# AA_3 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names AA_3 425
# FS get X len fs 8000
# 425 425 8000 (425, 8000)
# adding fs AA_4
# AA_4 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names AA_4 425
# FS get X len fs 160000
# 425 425 160000 (425, 160000)
# adding fs PC_5
# PC_5 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names PC_5 425
# FS get X len fs 16807
# 425 425 16807 (425, 16807)
# adding fs PC_6
# PC_6 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names PC_6 425
# FS get X len fs 117649
# 425 425 117649 (425, 117649)
# adding fs Domains_0
# Domains_0 <class 'str'>
# FS get sequences for length ds 425
# FS get feature names Domains_0 425
# FS get X len fs 832
# 425 425 832 (425, 832)
# {'AUC': 0.956, 'features': 'DNA', 'k': 2, 'Acc': 0.78, 'Spec': 0.93, 'Sens': 0.62, 'Prec': 0.89, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 1.0, 'features': 'DNA', 'k': 6, 'Acc': 0.85, 'Spec': 1.0, 'Sens': 0.69, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 0.978, 'features': 'DNA', 'k': 9, 'Acc': 0.85, 'Spec': 1.0, 'Sens': 0.69, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 0.967, 'features': 'AA', 'k': 3, 'Acc': 0.85, 'Spec': 1.0, 'Sens': 0.69, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 0.929, 'features': 'AA', 'k': 4, 'Acc': 0.7, 'Spec': 1.0, 'Sens': 0.38, 'Prec': 1.0, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 0.945, 'features': 'PC', 'k': 5, 'Acc': 0.78, 'Spec': 0.93, 'Sens': 0.62, 'Prec': 0.89, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 0.907, 'features': 'PC', 'k': 6, 'Acc': 0.67, 'Spec': 0.93, 'Sens': 0.38, 'Prec': 0.83, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# {'AUC': 0.78, 'features': 'Domains', 'k': 0, 'Acc': 0.67, 'Spec': 0.79, 'Sens': 0.54, 'Prec': 0.7, 'label': 'Lactobacillales', 'label_tax': 'order', 'pool_label': 'Firmicutes', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Myoviridae', 'N': 425}
# ***** ('Clostridiales', 'order', 'Firmicutes', 'phylum', 'DNA', 'Siphoviridae')
# Siphoviridae ('Clostridiales', 'order', 'Firmicutes', 'phylum', 'DNA')
# before ani -not_ho pos 25 neg 182
# after ani -not_ho pos 4 neg 170
# Clostridiales_Siphoviridae [25, 182, 4, 170]
# ho_pos 20 ho_neg 20 not_ho_pos 4 not_ho_neg 4
# holdout  Siphoviridae 48
#      virus  y      refseqs trn/tst
# 0   190478  1  [NC_003524]    test
# 1  1042123  1  [NC_019508]    test
# 2   864178  1  [NC_015262]    test
# 3   396359  1  [NC_008265]    test
# 4  1042124  1   [JF767210]    test
# ***** ('Clostridiales', 'order', 'Firmicutes', 'phylum', 'DNA', 'Myoviridae')
# Myoviridae ('Clostridiales', 'order', 'Firmicutes', 'phylum', 'DNA')
# before ani -not_ho pos 25 neg 470
# after ani -not_ho pos 11 neg 433
# Clostridiales_Myoviridae [25, 470, 11, 433]
# ho_pos 20 ho_neg 20 not_ho_pos 11 not_ho_neg 11
# holdout  Myoviridae 62
#      virus  y      refseqs trn/tst
# 0  1567012  1  [NC_028991]    test
# 1  1567014  1  [NC_029022]    test
# 2   320122  1  [NC_007917]    test
# 3  1582156  1  [NC_028883]    test
# 4    12336  1  [NC_007581]    test
# ***** ('Enterobacterales', 'order', 'Proteobacteria', 'phylum', 'DNA', 'Siphoviridae')
# Siphoviridae ('Enterobacterales', 'order', 'Proteobacteria', 'phylum', 'DNA')
# before ani -not_ho pos 472 neg 440
# after ani -not_ho pos 424 neg 433
# Enterobacterales_Siphoviridae [472, 440, 424, 433]
# ho_pos 20 ho_neg 20 not_ho_pos 200 not_ho_neg 200
# holdout  Siphoviridae 440
#      virus  y      refseqs trn/tst
# 0  1109721  1  [NC_016566]    test
# 1  1414766  1   [KF591601]    test
# 2  1567485  1  [NC_028812]    test
# 3  1073767  1  [NC_019509]    test
# 4  1610838  1  [NC_028997]    test
# OK************* 388
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0'] <class 'list'>
# adding fs DNA_2
# DNA_2 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names DNA_2 427
# FS get X len fs 16
# 427 427 16 (427, 16)
# adding fs DNA_6
# DNA_6 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names DNA_6 427
# FS get X len fs 4096
# 427 427 4096 (427, 4096)
# adding fs DNA_9
# DNA_9 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names DNA_9 427
# FS get X len fs 262144
# 427 427 262144 (427, 262144)
# adding fs AA_3
# AA_3 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names AA_3 427
# FS get X len fs 8000
# 427 427 8000 (427, 8000)
# adding fs AA_4
# AA_4 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names AA_4 427
# FS get X len fs 160000
# 427 427 160000 (427, 160000)
# adding fs PC_5
# PC_5 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names PC_5 427
# FS get X len fs 16807
# 427 427 16807 (427, 16807)
# adding fs PC_6
# PC_6 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names PC_6 427
# FS get X len fs 117649
# 427 427 117649 (427, 117649)
# adding fs Domains_0
# Domains_0 <class 'str'>
# FS get sequences for length ds 427
# FS get feature names Domains_0 427
# FS get X len fs 988
# 427 427 988 (427, 988)
# {'AUC': 0.613, 'features': 'DNA', 'k': 2, 'Acc': 0.46, 'Spec': 0.58, 'Sens': 0.35, 'Prec': 0.47, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.916, 'features': 'DNA', 'k': 6, 'Acc': 0.82, 'Spec': 0.89, 'Sens': 0.75, 'Prec': 0.88, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.884, 'features': 'DNA', 'k': 9, 'Acc': 0.77, 'Spec': 0.89, 'Sens': 0.65, 'Prec': 0.87, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.818, 'features': 'AA', 'k': 3, 'Acc': 0.56, 'Spec': 0.84, 'Sens': 0.3, 'Prec': 0.67, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.713, 'features': 'AA', 'k': 4, 'Acc': 0.49, 'Spec': 1.0, 'Sens': 0.0, 'Prec': 'NA', 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.589, 'features': 'PC', 'k': 5, 'Acc': 0.49, 'Spec': 0.79, 'Sens': 0.2, 'Prec': 0.5, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.489, 'features': 'PC', 'k': 6, 'Acc': 0.51, 'Spec': 1.0, 'Sens': 0.05, 'Prec': 1.0, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# {'AUC': 0.729, 'features': 'Domains', 'k': 0, 'Acc': 0.56, 'Spec': 0.89, 'Sens': 0.25, 'Prec': 0.71, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Siphoviridae', 'N': 427}
# ***** ('Enterobacterales', 'order', 'Proteobacteria', 'phylum', 'DNA', 'Podoviridae')
# Podoviridae ('Enterobacterales', 'order', 'Proteobacteria', 'phylum', 'DNA')
# before ani -not_ho pos 447 neg 401
# after ani -not_ho pos 404 neg 391
# Enterobacterales_Podoviridae [447, 401, 404, 391]
# ho_pos 20 ho_neg 20 not_ho_pos 200 not_ho_neg 200
# holdout  Podoviridae 440
#      virus  y      refseqs trn/tst
# 0  1647458  1  [NC_028696]    test
# 1  1527506  1  [NC_027387]    test
# 2   227720  1  [NC_004777]    test
# 3   979726  1  [NC_020414]    test
# 4   221029  1  [NC_005841]    test
# OK************* 384
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0'] <class 'list'>
# adding fs DNA_2
# DNA_2 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names DNA_2 424
# FS get X len fs 16
# 424 424 16 (424, 16)
# adding fs DNA_6
# DNA_6 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names DNA_6 424
# FS get X len fs 4096
# 424 424 4096 (424, 4096)
# adding fs DNA_9
# DNA_9 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names DNA_9 424
# FS get X len fs 262144
# 424 424 262144 (424, 262144)
# adding fs AA_3
# AA_3 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names AA_3 424
# FS get X len fs 8000
# 424 424 8000 (424, 8000)
# adding fs AA_4
# AA_4 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names AA_4 424
# FS get X len fs 160000
# 424 424 160000 (424, 160000)
# adding fs PC_5
# PC_5 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names PC_5 424
# FS get X len fs 16807
# 424 424 16807 (424, 16807)
# adding fs PC_6
# PC_6 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names PC_6 424
# FS get X len fs 117649
# 424 424 117649 (424, 117649)
# adding fs Domains_0
# Domains_0 <class 'str'>
# FS get sequences for length ds 424
# FS get feature names Domains_0 424
# FS get X len fs 1035
# 424 424 1035 (424, 1035)
# {'AUC': 0.69, 'features': 'DNA', 'k': 2, 'Acc': 0.62, 'Spec': 0.3, 'Sens': 0.95, 'Prec': 0.58, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.94, 'features': 'DNA', 'k': 6, 'Acc': 0.8, 'Spec': 0.75, 'Sens': 0.85, 'Prec': 0.77, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.932, 'features': 'DNA', 'k': 9, 'Acc': 0.85, 'Spec': 0.85, 'Sens': 0.85, 'Prec': 0.85, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.805, 'features': 'AA', 'k': 3, 'Acc': 0.7, 'Spec': 0.95, 'Sens': 0.45, 'Prec': 0.9, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.742, 'features': 'AA', 'k': 4, 'Acc': 0.53, 'Spec': 1.0, 'Sens': 0.05, 'Prec': 1.0, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.592, 'features': 'PC', 'k': 5, 'Acc': 0.55, 'Spec': 0.9, 'Sens': 0.2, 'Prec': 0.67, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.732, 'features': 'PC', 'k': 6, 'Acc': 0.53, 'Spec': 1.0, 'Sens': 0.05, 'Prec': 1.0, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# {'AUC': 0.752, 'features': 'Domains', 'k': 0, 'Acc': 0.65, 'Spec': 0.65, 'Sens': 0.65, 'Prec': 0.65, 'label': 'Enterobacterales', 'label_tax': 'order', 'pool_label': 'Proteobacteria', 'pool_tax': 'phylum', 'Baltimore': 'DNA', 'holdout': 'Podoviridae', 'N': 424}
# ***** ('Enterobacterales', 'order', 'Proteobacteria', 'phylum', 'DNA', 'Myoviridae')
# Myoviridae ('Enterobacterales', 'order', 'Proteobacteria', 'phylum', 'DNA')
# before ani -not_ho pos 419 neg 387
# after ani -not_ho pos 365 neg 379
# Enterobacterales_Myoviridae [419, 387, 365, 379]
# ho_pos 20 ho_neg 20 not_ho_pos 200 not_ho_neg 200
# holdout  Myoviridae 440
#      virus  y      refseqs trn/tst
# 0  1407493  1  [NC_022749]    test
# 1  1718669  1  [NC_028935]    test
# 2  1206560  1  [NC_027353]    test
# 3  1719140  1  [NC_028659]    test
# 4  1857100  1  [NC_031939]    test
# OK************* 390
# ['DNA_2', 'DNA_6', 'DNA_9', 'AA_3', 'AA_4', 'PC_5', 'PC_6', 'Domains_0'] <class 'list'>
# adding fs DNA_2
# DNA_2 <class 'str'>
# FS get sequences for length ds 430
# FS get feature names DNA_2 430
# FS get X len fs 16
# 430 430 16 (430, 16)
