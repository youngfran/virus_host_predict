# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as s

# %% [markdown]
# ## Heatmaps of main results

# %%
resultsfile = 'Bact_holdout_results.csv'
results = pd.read_csv(resultsfile)
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 15 columns):
# positive label         384 non-null object
# label tax group        384 non-null object
# pool label             384 non-null object
# pool tax group         384 non-null object
# Baltimore              384 non-null object
# virus holdout group    384 non-null object
# training group         384 non-null object
# N in class             384 non-null int64
# Features               384 non-null object
# k                      384 non-null int64
# AUC                    384 non-null float64
# accuracy               384 non-null float64
# specificity            384 non-null float64
# sensitivity            384 non-null float64
# TN/FP/FN/TP            384 non-null object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 45.1+ KB

# %% [markdown]
# ### Add DNA_2 file

# %%
resultsDNA2file = 'Bact_holdout_dna2_results.csv'
resultsDNA2 = pd.read_csv(resultsDNA2file)

resdf = pd.concat([results,resultsDNA2])
results = resdf
resdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 432 entries, 0 to 47
# Data columns (total 15 columns):
# positive label         432 non-null object
# label tax group        432 non-null object
# pool label             432 non-null object
# pool tax group         432 non-null object
# Baltimore              432 non-null object
# virus holdout group    432 non-null object
# training group         432 non-null object
# N in class             432 non-null int64
# Features               432 non-null object
# k                      432 non-null int64
# AUC                    432 non-null float64
# accuracy               432 non-null float64
# specificity            432 non-null float64
# sensitivity            432 non-null float64
# TN/FP/FN/TP            432 non-null object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 54.0+ KB

# %%
correct_tg = lambda row:'Holdout' if row['training group']== 'oldout' else row['training group']
results['training_group']= results.apply(correct_tg , axis=1)
results.drop(['training group'], axis = 1, inplace = True)

concat_ds = lambda row: f'{row["virus holdout group"]}_{row["positive label"]}_{row["training_group"]}'
results['Dataset']= results.apply(concat_ds , axis=1)


concat_fs = lambda row : f'{row["Features"]}_{row["k"]}'
results['Feature set']= results.apply(concat_fs , axis=1)

# %%
tax_order =['p','c','o','f','g','s']
fs_order =['DNA_2','DNA_3','DNA_6','DNA_9','AA_3','AA_4','PC_5','PC_6','Domain_1']
#ds_list = list(set(results['dataset']))
#df.apply(lambda row: row['task'].split('_')[1] , axis=1)
results['tax'] = results.apply(lambda row: row['label tax group'][0], axis = 1)
results['tax'] = results['tax'].astype('category')
results['tax'].cat.set_categories(tax_order, inplace=True)
results['Feature set'] = results['Feature set'].astype('category')
results['Feature set'].cat.set_categories(fs_order, inplace=True)

# %%
results.head(30)
# Out:
#     positive label label tax group pool label pool tax group Baltimore  \
# 0    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 1    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 2    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 3    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 4    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 5    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 6    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 7    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 8    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 9    Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 10   Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 11   Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 12   Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 13   Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 14   Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 15   Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 16  Actinobacteria           class   Bacteria        kingdom       DNA
# 17  Actinobacteria           class   Bacteria        kingdom       DNA
# 18  Actinobacteria           class   Bacteria        kingdom       DNA
# 19  Actinobacteria           class   Bacteria        kingdom       DNA
# 20  Actinobacteria           class   Bacteria        kingdom       DNA
# 21  Actinobacteria           class   Bacteria        kingdom       DNA
# 22  Actinobacteria           class   Bacteria        kingdom       DNA
# 23  Actinobacteria           class   Bacteria        kingdom       DNA
# 24  Actinobacteria           class   Bacteria        kingdom       DNA
# 25  Actinobacteria           class   Bacteria        kingdom       DNA
# 26  Actinobacteria           class   Bacteria        kingdom       DNA
# 27  Actinobacteria           class   Bacteria        kingdom       DNA
# 28  Actinobacteria           class   Bacteria        kingdom       DNA
# 29  Actinobacteria           class   Bacteria        kingdom       DNA
#
#    virus holdout group  N in class Features  k    AUC  accuracy  specificity  \
# 0         Siphoviridae          63      DNA  3  0.950     0.804        0.690
# 1         Siphoviridae          63      DNA  6  0.989     0.941        1.000
# 2         Siphoviridae          63      DNA  9  0.980     0.588        1.000
# 3         Siphoviridae          63       AA  3  0.975     0.569        1.000
# 4         Siphoviridae          63       AA  4  0.917     0.569        1.000
# 5         Siphoviridae          63       PC  5  0.862     0.569        1.000
# 6         Siphoviridae          63       PC  6  0.868     0.569        1.000
# 7         Siphoviridae          63   Domain  1  0.458     0.588        0.897
# 8         Siphoviridae          89      DNA  3  0.955     0.900        0.812
# 9         Siphoviridae          89      DNA  6  1.000     0.933        0.875
# 10        Siphoviridae          89      DNA  9  1.000     0.967        0.938
# 11        Siphoviridae          89       AA  3  1.000     1.000        1.000
# 12        Siphoviridae          89       AA  4  1.000     0.897        1.000
# 13        Siphoviridae          89       PC  5  0.986     0.862        1.000
# 14        Siphoviridae          89       PC  6  0.981     0.862        1.000
# 15        Siphoviridae          89   Domain  1  0.986     0.966        0.933
# 16        Siphoviridae          86      DNA  3  0.974     0.929        0.940
# 17        Siphoviridae          86      DNA  6  0.982     0.857        0.940
# 18        Siphoviridae          86      DNA  9  0.935     0.816        0.880
# 19        Siphoviridae          86       AA  3  0.979     0.929        0.900
# 20        Siphoviridae          86       AA  4  0.960     0.510        1.000
# 21        Siphoviridae          86       PC  5  0.927     0.602        1.000
# 22        Siphoviridae          86       PC  6  0.930     0.510        1.000
# 23        Siphoviridae          86   Domain  1  0.836     0.612        1.000
# 24        Siphoviridae         539      DNA  3  0.999     0.990        1.000
# 25        Siphoviridae         539      DNA  6  1.000     0.995        1.000
# 26        Siphoviridae         539      DNA  9  1.000     0.995        1.000
# 27        Siphoviridae         539       AA  3  1.000     0.990        1.000
# 28        Siphoviridae         539       AA  4  0.999     0.986        1.000
# 29        Siphoviridae         539       PC  5  1.000     0.986        1.000
#
#     sensitivity        TN/FP/FN/TP training_group  \
# 0         0.955      [20  9  1 21]        Holdout
# 1         0.864      [29  0  3 19]        Holdout
# 2         0.045      [29  0 21  1]        Holdout
# 3         0.000      [29  0 22  0]        Holdout
# 4         0.000      [29  0 22  0]        Holdout
# 5         0.000      [29  0 22  0]        Holdout
# 6         0.000      [29  0 22  0]        Holdout
# 7         0.182      [26  3 18  4]        Holdout
# 8         1.000      [13  3  0 14]            All
# 9         1.000      [14  2  0 14]            All
# 10        1.000      [15  1  0 14]            All
# 11        1.000      [15  0  0 14]            All
# 12        0.786      [15  0  3 11]            All
# 13        0.714      [15  0  4 10]            All
# 14        0.714      [15  0  4 10]            All
# 15        1.000      [14  1  0 14]            All
# 16        0.917      [47  3  4 44]        Holdout
# 17        0.771      [47  3 11 37]        Holdout
# 18        0.750      [44  6 12 36]        Holdout
# 19        0.958      [45  5  2 46]        Holdout
# 20        0.000      [50  0 48  0]        Holdout
# 21        0.188      [50  0 39  9]        Holdout
# 22        0.000      [50  0 48  0]        Holdout
# 23        0.208      [50  0 38 10]        Holdout
# 24        0.980  [110   0   2  98]            All
# 25        0.990  [110   0   1  99]            All
# 26        0.990  [110   0   1  99]            All
# 27        0.980  [109   0   2  98]            All
# 28        0.970  [109   0   3  97]            All
# 29        0.970  [109   0   3  97]            All
#
#                                 Dataset Feature set tax
# 0    Siphoviridae_Bacteroidetes_Holdout       DNA_3   p
# 1    Siphoviridae_Bacteroidetes_Holdout       DNA_6   p
# 2    Siphoviridae_Bacteroidetes_Holdout       DNA_9   p
# 3    Siphoviridae_Bacteroidetes_Holdout        AA_3   p
# 4    Siphoviridae_Bacteroidetes_Holdout        AA_4   p
# 5    Siphoviridae_Bacteroidetes_Holdout        PC_5   p
# 6    Siphoviridae_Bacteroidetes_Holdout        PC_6   p
# 7    Siphoviridae_Bacteroidetes_Holdout    Domain_1   p
# 8        Siphoviridae_Bacteroidetes_All       DNA_3   p
# 9        Siphoviridae_Bacteroidetes_All       DNA_6   p
# 10       Siphoviridae_Bacteroidetes_All       DNA_9   p
# 11       Siphoviridae_Bacteroidetes_All        AA_3   p
# 12       Siphoviridae_Bacteroidetes_All        AA_4   p
# 13       Siphoviridae_Bacteroidetes_All        PC_5   p
# 14       Siphoviridae_Bacteroidetes_All        PC_6   p
# 15       Siphoviridae_Bacteroidetes_All    Domain_1   p
# 16  Siphoviridae_Actinobacteria_Holdout       DNA_3   c
# 17  Siphoviridae_Actinobacteria_Holdout       DNA_6   c
# 18  Siphoviridae_Actinobacteria_Holdout       DNA_9   c
# 19  Siphoviridae_Actinobacteria_Holdout        AA_3   c
# 20  Siphoviridae_Actinobacteria_Holdout        AA_4   c
# 21  Siphoviridae_Actinobacteria_Holdout        PC_5   c
# 22  Siphoviridae_Actinobacteria_Holdout        PC_6   c
# 23  Siphoviridae_Actinobacteria_Holdout    Domain_1   c
# 24      Siphoviridae_Actinobacteria_All       DNA_3   c
# 25      Siphoviridae_Actinobacteria_All       DNA_6   c
# 26      Siphoviridae_Actinobacteria_All       DNA_9   c
# 27      Siphoviridae_Actinobacteria_All        AA_3   c
# 28      Siphoviridae_Actinobacteria_All        AA_4   c
# 29      Siphoviridae_Actinobacteria_All        PC_5   c

# %%
taxlevels = ['phylum','order']
for i, t in enumerate(taxlevels):
    
    ss= results[results.tax == t[0]]
    #nds =len(set(ss['Dataset']))
    #print(round(s.mean(list(set(ss['N in class']))),1))
    

    results_p = results[results.tax == t[0]]
    #n =round(s.mean(list(set(ss['N in class']))),1)
    sns.set(font_scale=1.8, palette = 'viridis')
    #grid.map(sns.boxplot, x='Feature set',y= "AUC",hue = "k" ,saturation =1,  width =0.9, data = results)
    f, ax = plt.subplots(figsize=(20, 10))
    plt.xticks(rotation='vertical')
    plt.title(f' {taxlevels[i]} Level AUC Scores ')
    b = sns.boxplot( x = 'Feature set', y ='AUC', hue = 'training_group',width =0.6,linewidth =1.5,dodge = True, 
                ax =ax, data = results_p)

# sp = sns.swarmplot(data = results_p,x = 'Feature set',
#                      y = 'AUC',hue = 'Features',
#                     size = 3, dodge = True)

 #   f.savefig(f'Figures/{taxlevels[i]}_bxplt_Bact_DNA.png')

# %%
results.sort_values(by = ['tax','positive label'],inplace=True)

# %%
df_sp_sn = results[['Dataset', 'Feature set', 'specificity', 'sensitivity','training_group']]
for s in ['specificity']: #, 'sensitivity']:
    f, ax = plt.subplots(figsize=(20, 10))
    plt.xticks(rotation='vertical')
    sns.boxplot ( x = 'Feature set', y =s, hue = 'training_group',width =0.6,linewidth =1.5,dodge = True, 
                     ax = ax,data =df_sp_sn)
f.savefig(f'Figures/spe_bxplt_Bact.svg')

# %%
results.head()
# Out:
#   positive label label tax group pool label pool tax group Baltimore  \
# 0  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 1  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 0  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 8  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 1  Bacteroidetes          phylum   Bacteria        kingdom       DNA
#
#   virus holdout group  N in class Features  k    AUC  accuracy  specificity  \
# 0        Siphoviridae          64      DNA  2  0.572     0.529        0.448
# 1        Siphoviridae          89      DNA  2  0.951     0.867        0.750
# 0        Siphoviridae          63      DNA  3  0.950     0.804        0.690
# 8        Siphoviridae          89      DNA  3  0.955     0.900        0.812
# 1        Siphoviridae          63      DNA  6  0.989     0.941        1.000
#
#    sensitivity    TN/FP/FN/TP training_group  \
# 0        0.636  [13 16  8 14]        Holdout
# 1        1.000  [12  4  0 14]            All
# 0        0.955  [20  9  1 21]        Holdout
# 8        1.000  [13  3  0 14]            All
# 1        0.864  [29  0  3 19]        Holdout
#
#                               Dataset Feature set tax
# 0  Siphoviridae_Bacteroidetes_Holdout       DNA_2   p
# 1      Siphoviridae_Bacteroidetes_All       DNA_2   p
# 0  Siphoviridae_Bacteroidetes_Holdout       DNA_3   p
# 8      Siphoviridae_Bacteroidetes_All       DNA_3   p
# 1  Siphoviridae_Bacteroidetes_Holdout       DNA_6   p

# %%
unique =[]
[unique.append(ds) for ds in(list(results['Dataset']))if ds not in unique ]
unique
# Out:
# ['Siphoviridae_Bacteroidetes_Holdout',
#  'Siphoviridae_Bacteroidetes_All',
#  'Siphoviridae_Actinobacteria_Holdout',
#  'Siphoviridae_Actinobacteria_All',
#  'Siphoviridae_Firmicutes_Holdout',
#  'Siphoviridae_Firmicutes_All',
#  'Siphoviridae_Proteobacteria_Holdout',
#  'Siphoviridae_Proteobacteria_All',
#  'Podoviridae_Cyanobacteria_Holdout',
#  'Podoviridae_Cyanobacteria_All',
#  'Podoviridae_Firmicutes_Holdout',
#  'Podoviridae_Firmicutes_All',
#  'Podoviridae_Proteobacteria_Holdout',
#  'Podoviridae_Proteobacteria_All',
#  'Myoviridae_Cyanobacteria_Holdout',
#  'Myoviridae_Cyanobacteria_All',
#  'Myoviridae_Firmicutes_Holdout',
#  'Myoviridae_Firmicutes_All',
#  'Myoviridae_Proteobacteria_Holdout',
#  'Myoviridae_Proteobacteria_All',
#  'Siphoviridae_Bacillales_Holdout',
#  'Siphoviridae_Bacillales_All',
#  'Myoviridae_Bacillales_Holdout',
#  'Myoviridae_Bacillales_All',
#  'Podoviridae_Bacillales_Holdout',
#  'Podoviridae_Bacillales_All',
#  'Siphoviridae_Lactobacillales_Holdout',
#  'Siphoviridae_Lactobacillales_All',
#  'Myoviridae_Lactobacillales_Holdout',
#  'Myoviridae_Lactobacillales_All',
#  'Siphoviridae_Clostridiales_Holdout',
#  'Siphoviridae_Clostridiales_All',
#  'Myoviridae_Clostridiales_Holdout',
#  'Myoviridae_Clostridiales_All',
#  'Siphoviridae_Enterobacterales_Holdout',
#  'Siphoviridae_Enterobacterales_All',
#  'Podoviridae_Enterobacterales_Holdout',
#  'Podoviridae_Enterobacterales_All',
#  'Myoviridae_Enterobacterales_Holdout',
#  'Myoviridae_Enterobacterales_All',
#  'Myoviridae_Pseudomonadales_Holdout',
#  'Myoviridae_Pseudomonadales_All',
#  'Podoviridae_Pseudomonadales_Holdout',
#  'Podoviridae_Pseudomonadales_All',
#  'Siphoviridae_Pseudomonadales_Holdout',
#  'Siphoviridae_Pseudomonadales_All',
#  'Siphoviridae_Bacillaceae_Holdout',
#  'Siphoviridae_Bacillaceae_All']

# %%
dfn  =  results[~(results['Feature set'].isin(['DNA_3'])) ]

# %%
df1 = dfn.pivot( 'Feature set','Dataset', 'AUC')
#df1 = df.reindex(unique)

# %%
sns.set(font_scale=1.5, palette = 'viridis')
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(20, 8))
plt.xticks(rotation='vertical')
ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    top=False,      # ticks along the bottom edge are off
     bottom=False,         # ticks along the top edge are off
    labelbottom=False
    )
ax.set_ylabel(ax.get_ylabel(), fontsize=25)
ax.set_xlabel(ax.get_xlabel(), fontsize=25)
sns.heatmap(df1,cmap = 'viridis', vmin = 0.5,   ax=ax)

# %%
f.savefig('Figures/heatmap_HO_Bact_no_ds.png', bbox_inches="tight")

# %% [markdown]
# ### Sort the dataset order

# %%
ho_df = results[results.training_group=='Holdout']
ho_df = ho_df.rename(columns={'AUC':'ho_AUC'})
ho_df = ho_df[['Dataset','Feature set','tax','ho_AUC']]


ho_df['Dataset']= ho_df.apply( lambda row: row['Dataset'][:-8] , axis=1)

# %%
ho_df.head()
# Out:
#                       Dataset Feature set tax  ho_AUC
# 0  Siphoviridae_Bacteroidetes       DNA_3   p   0.950
# 1  Siphoviridae_Bacteroidetes       DNA_6   p   0.989
# 2  Siphoviridae_Bacteroidetes       DNA_9   p   0.980
# 3  Siphoviridae_Bacteroidetes        AA_3   p   0.975
# 4  Siphoviridae_Bacteroidetes        AA_4   p   0.917

# %%
results.head()
# Out:
#   positive label label tax group pool label pool tax group Baltimore  \
# 0  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 1  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 2  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 3  Bacteroidetes          phylum   Bacteria        kingdom       DNA
# 4  Bacteroidetes          phylum   Bacteria        kingdom       DNA
#
#   virus holdout group  N in class Features  k    AUC  accuracy  specificity  \
# 0        Siphoviridae          63      DNA  3  0.950     0.804         0.69
# 1        Siphoviridae          63      DNA  6  0.989     0.941         1.00
# 2        Siphoviridae          63      DNA  9  0.980     0.588         1.00
# 3        Siphoviridae          63       AA  3  0.975     0.569         1.00
# 4        Siphoviridae          63       AA  4  0.917     0.569         1.00
#
#    sensitivity    TN/FP/FN/TP training_group  \
# 0        0.955  [20  9  1 21]        Holdout
# 1        0.864  [29  0  3 19]        Holdout
# 2        0.045  [29  0 21  1]        Holdout
# 3        0.000  [29  0 22  0]        Holdout
# 4        0.000  [29  0 22  0]        Holdout
#
#                               Dataset Feature set tax
# 0  Siphoviridae_Bacteroidetes_Holdout       DNA_3   p
# 1  Siphoviridae_Bacteroidetes_Holdout       DNA_6   p
# 2  Siphoviridae_Bacteroidetes_Holdout       DNA_9   p
# 3  Siphoviridae_Bacteroidetes_Holdout        AA_3   p
# 4  Siphoviridae_Bacteroidetes_Holdout        AA_4   p

# %%
all_df = results[results.training_group=='All']

# %%
all_df = all_df.rename(columns={'AUC':'all_AUC'})

# %%
all_df = all_df[['Dataset','Feature set','tax','all_AUC']]

# %%
all_df.head()
# Out:
#                            Dataset Feature set tax  all_AUC
# 8   Siphoviridae_Bacteroidetes_All       DNA_3   p    0.955
# 9   Siphoviridae_Bacteroidetes_All       DNA_6   p    1.000
# 10  Siphoviridae_Bacteroidetes_All       DNA_9   p    1.000
# 11  Siphoviridae_Bacteroidetes_All        AA_3   p    1.000
# 12  Siphoviridae_Bacteroidetes_All        AA_4   p    1.000

# %%
all_df['Dataset']= all_df.apply( lambda row: row['Dataset'][:-4] , axis=1)
all_df.head()
# Out:
#                        Dataset Feature set tax  all_AUC
# 8   Siphoviridae_Bacteroidetes       DNA_3   p    0.955
# 9   Siphoviridae_Bacteroidetes       DNA_6   p    1.000
# 10  Siphoviridae_Bacteroidetes       DNA_9   p    1.000
# 11  Siphoviridae_Bacteroidetes        AA_3   p    1.000
# 12  Siphoviridae_Bacteroidetes        AA_4   p    1.000

# %%
ratios_df = pd.merge(all_df,ho_df, on= ['Dataset','Feature set'])
ratios_df.head()
ratios_df['ratios']= ratios_df.apply( lambda row:  row['ho_AUC']/row['all_AUC']  , axis=1)

# %%
#row:'Holdout' if row['training group']== 'oldout' else row['training group']
a= ratios_df['ho_AUC']-0.5
b= ratios_df['all_AUC']- 0.5 

ratios_df['ratios2'] =((ratios_df['ho_AUC']-0.5)/(ratios_df['all_AUC']- 0.5)).replace(np.inf,1)

#ratios_df['ratios']= ratios_df.apply( lambda row:  row['ho_AUC']/row['all_AUC']  , axis=1)
#
ratios_df['ratio3']= ratios_df.apply( lambda row:  (row['ho_AUC']-0.5)/(row['all_AUC']- 0.5 ) , axis=1)

# %%
fs_order =['DNA_2','DNA_6','DNA_9','AA_3','AA_4','PC_5','PC_6','Domain_1']

ratios_df.head()
# Out:
#                       Dataset Feature set tax_x  all_AUC tax_y  ho_AUC  \
# 0  Siphoviridae_Bacteroidetes       DNA_3     p    0.955     p   0.950
# 1  Siphoviridae_Bacteroidetes       DNA_6     p    1.000     p   0.989
# 2  Siphoviridae_Bacteroidetes       DNA_9     p    1.000     p   0.980
# 3  Siphoviridae_Bacteroidetes        AA_3     p    1.000     p   0.975
# 4  Siphoviridae_Bacteroidetes        AA_4     p    1.000     p   0.917
#
#      ratios   ratios2    ratio3   ratios4
# 0  0.994764  0.989011  0.989011  0.989011
# 1  0.989000  0.978000  0.978000  0.978000
# 2  0.980000  0.960000  0.960000  0.960000
# 3  0.975000  0.950000  0.950000  0.950000
# 4  0.917000  0.834000  0.834000  0.834000

# %%
ratios_df['ratios4']= ratios_df.apply( lambda row:  row ['ratio3'] if row['ratio3'] <= 1  else 1 , axis=1)
ratios_df['ratios4']= ratios_df.apply( lambda row:  row ['ratios4'] if row['ratios4'] >0  else 0 , axis=1)

# %%
from collections import Counter
bad_fs = Counter(list(ratios_df[ (ratios_df['ratios'] < 0.75)]['Feature set']))
bad_fs
# Out:
# Counter({'AA_4': 3, 'DNA_2': 4, 'Domain_1': 6, 'PC_5': 6, 'PC_6': 7})

# %%
ratios_df[ratios_df.ratios4 >1 ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-474-8b832447c2b7> in <module>()
#       1
# ----> 2 ratios_df[ratios_df.ratios4 >1 ]
#
# ~/Desktop/workspace/myenv/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ratios4'

# %%
#concat_ds = lambda row: f'{row["virus holdout group"]}_{row["positive label"]}_{row["training_group"]}'
#results['Dataset']= results.apply(concat_ds , axis=1)
ds=  lambda row:  f'{row ["Dataset"].split("_")[1]}_{row ["Dataset"].split("_")[0]}' 
ratios_df['DS'] = ratios_df.apply (ds, axis =1)

# %%
#df1 = ratios_df.sort_values('tax_x')
unique =[]
[unique.append(ds) for ds in(list(results['Dataset']))if ds not in unique ]
unique
# Out:
# ['Siphoviridae_Bacteroidetes_Holdout',
#  'Siphoviridae_Bacteroidetes_All',
#  'Siphoviridae_Actinobacteria_Holdout',
#  'Siphoviridae_Actinobacteria_All',
#  'Siphoviridae_Firmicutes_Holdout',
#  'Siphoviridae_Firmicutes_All',
#  'Siphoviridae_Proteobacteria_Holdout',
#  'Siphoviridae_Proteobacteria_All',
#  'Podoviridae_Cyanobacteria_Holdout',
#  'Podoviridae_Cyanobacteria_All',
#  'Podoviridae_Firmicutes_Holdout',
#  'Podoviridae_Firmicutes_All',
#  'Podoviridae_Proteobacteria_Holdout',
#  'Podoviridae_Proteobacteria_All',
#  'Myoviridae_Cyanobacteria_Holdout',
#  'Myoviridae_Cyanobacteria_All',
#  'Myoviridae_Firmicutes_Holdout',
#  'Myoviridae_Firmicutes_All',
#  'Myoviridae_Proteobacteria_Holdout',
#  'Myoviridae_Proteobacteria_All',
#  'Siphoviridae_Bacillales_Holdout',
#  'Siphoviridae_Bacillales_All',
#  'Myoviridae_Bacillales_Holdout',
#  'Myoviridae_Bacillales_All',
#  'Podoviridae_Bacillales_Holdout',
#  'Podoviridae_Bacillales_All',
#  'Siphoviridae_Lactobacillales_Holdout',
#  'Siphoviridae_Lactobacillales_All',
#  'Myoviridae_Lactobacillales_Holdout',
#  'Myoviridae_Lactobacillales_All',
#  'Siphoviridae_Clostridiales_Holdout',
#  'Siphoviridae_Clostridiales_All',
#  'Myoviridae_Clostridiales_Holdout',
#  'Myoviridae_Clostridiales_All',
#  'Siphoviridae_Enterobacterales_Holdout',
#  'Siphoviridae_Enterobacterales_All',
#  'Podoviridae_Enterobacterales_Holdout',
#  'Podoviridae_Enterobacterales_All',
#  'Myoviridae_Enterobacterales_Holdout',
#  'Myoviridae_Enterobacterales_All',
#  'Myoviridae_Pseudomonadales_Holdout',
#  'Myoviridae_Pseudomonadales_All',
#  'Podoviridae_Pseudomonadales_Holdout',
#  'Podoviridae_Pseudomonadales_All',
#  'Siphoviridae_Pseudomonadales_Holdout',
#  'Siphoviridae_Pseudomonadales_All',
#  'Siphoviridae_Bacillaceae_Holdout',
#  'Siphoviridae_Bacillaceae_All']

# %%
unique1 =[ f'{s.split("_")[1]}_{s.split("_")[0]}' for s in unique ]
unique2 =[]
[unique2.append(ds) for ds in unique1 if ds not in unique2 ]
(unique2.sort())
unique2
# Out:
# ['Actinobacteria_Siphoviridae',
#  'Bacillaceae_Siphoviridae',
#  'Bacillales_Myoviridae',
#  'Bacillales_Podoviridae',
#  'Bacillales_Siphoviridae',
#  'Bacteroidetes_Siphoviridae',
#  'Clostridiales_Myoviridae',
#  'Clostridiales_Siphoviridae',
#  'Cyanobacteria_Myoviridae',
#  'Cyanobacteria_Podoviridae',
#  'Enterobacterales_Myoviridae',
#  'Enterobacterales_Podoviridae',
#  'Enterobacterales_Siphoviridae',
#  'Firmicutes_Myoviridae',
#  'Firmicutes_Podoviridae',
#  'Firmicutes_Siphoviridae',
#  'Lactobacillales_Myoviridae',
#  'Lactobacillales_Siphoviridae',
#  'Proteobacteria_Myoviridae',
#  'Proteobacteria_Podoviridae',
#  'Proteobacteria_Siphoviridae',
#  'Pseudomonadales_Myoviridae',
#  'Pseudomonadales_Podoviridae',
#  'Pseudomonadales_Siphoviridae']

# %%
ratios_df['ratios5']= ratios_df.apply( lambda row:  row ['ratios'] if row['ratios'] <= 1  else 1 , axis=1)
ratios_df['ratios5']= ratios_df.apply( lambda row:  row ['ratios5'] if row['ratios5'] >0.5  else 0.5 , axis=1)

# %%
df = ratios_df.pivot('DS','Feature set', 'ratios5')
#df2 = df.reindex(unique2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Actinobacteria_Siphoviridae to Pseudomonadales_Siphoviridae
# Data columns (total 8 columns):
# DNA_2       24 non-null float64
# DNA_6       24 non-null float64
# DNA_9       24 non-null float64
# AA_3        24 non-null float64
# AA_4        24 non-null float64
# PC_5        24 non-null float64
# PC_6        24 non-null float64
# Domain_1    24 non-null float64
# dtypes: float64(8)
# memory usage: 1.7+ KB

# %%
# Draw a heatmap with the numeric values in each cell
#sns.set(font_scale=2)
f, ax = plt.subplots(figsize=(10, 15))

sns.heatmap(df,cmap = 'viridis',  ax=ax) #min = 0.5,vmax = 1.0 
plt.ylabel ( 'Dataset' )
f.savefig('Figures/heatmap_ratios_Bact.png', bbox_inches="tight", dpi=500)

# %%
# label_order = ['Metazoa','Chordata','Mammalia','Primates']
# balt_order = ['dsDNA','ssDNA', '(-)ssRNA' , '(+)ssRNA','dsRNA', 'Retro']
# df['label'] = df['label'].astype("category")
# df['label'].cat.set_categories(label_order, inplace=True)
# df['baltimore'] = df['baltimore'].astype("category")
# df['baltimore'].cat.set_categories(balt_order, inplace=True)

# dfA = df.sort_values(["label","baltimore","X"])

# %%
#sales.query('CustomerID not in @badcu') df = df[df.line_race != 0]
fs2drop = ['DNA_3']
#ss= df[df.tax == t]
df = ratios_df[ratios_df['Feature set'] != 'DNA_3'] 
fs_order =['DNA_2','DNA_6','DNA_9','AA_3','AA_4','PC_5','PC_6','Domain_1']
set(df['Feature set'])
# Out:
# {'AA_3', 'AA_4', 'DNA_2', 'DNA_6', 'DNA_9', 'Domain_1', 'PC_5', 'PC_6'}

# %%
ratios_df['Feature set'].cat.set_categories(fs_order, inplace=True)

# %%
g, ax = plt.subplots(figsize=(20, 10))
#
#plt.xticks(rotation='vertical')
#plt.title(f' Ratios  ALL_AUC:HO_AUC ')
f = sns.violinplot( x = 'Feature set', y ='ratios5',  palette = 'viridis',width = 1.1,bw = .3,
                ax =ax, data = ratios_df)
plt.xticks(rotation='vertical')
plt.ylabel ( 'Ratio AUC_ho: AUC_all' )
#ax.set(ylim = (0,1.25) ) 
#f = sns.catplot( x = 'Feature set', y ='ratios2', kind = 'violin',  palette = 'viridis',#width = 1,
 #               ax =ax, data = ratios_df)
#sns.swarmplot( x = 'Feature set', y ='ratio', cut = 1,
#                ax =ax, data = ratios_df)
g.savefig('Figures/violinplot_ratios_Bact.png', bbox_inches="tight", dpi=500)
# Out:
# /home4/youn01f/Desktop/workspace/myenv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g.savefig('Figures/violinplot_ratios_Bact.svg', bbox_inches="tight", dpi=500)

# %%
ratios_df.groupby(['Feature set']).std()
# Out:
#               all_AUC    ho_AUC     ratio
# Feature set
# DNA_2        0.112700  0.120090  0.134802
# DNA_3        0.047361  0.073162  0.074473
# DNA_6        0.008404  0.042503  0.040464
# DNA_9        0.008293  0.050033  0.046445
# AA_3         0.011728  0.066317  0.064746
# AA_4         0.010070  0.124865  0.122872
# PC_5         0.012597  0.138367  0.133442
# PC_6         0.011889  0.136720  0.134048
# Domain_1     0.016116  0.160264  0.155522

# %%
ratios_df.groupby(['Feature set']).mean()
# Out:
#               all_AUC    ho_AUC     ratio
# Feature set
# DNA_2        0.856000  0.776667  0.914944
# DNA_3        0.955708  0.890167  0.932399
# DNA_6        0.994750  0.963667  0.968694
# DNA_9        0.994792  0.952125  0.956939
# AA_3         0.990833  0.939375  0.947967
# AA_4         0.989750  0.881583  0.890271
# PC_5         0.986417  0.831083  0.841515
# PC_6         0.988292  0.822958  0.832185
# Domain_1     0.982792  0.817750  0.830745

# %%
ratios_df.groupby('Feature set')['ratios'].apply (lambda x: x[x < 0.75].count())
# Out:
# Feature set
# DNA_2       4
# DNA_6       0
# DNA_9       0
# AA_3        0
# AA_4        3
# PC_5        6
# PC_6        7
# Domain_1    6
# Name: ratios, dtype: int64

# %%
df.groupby('key1')['key2'].apply(lambda x: x[x == 'one'].count())

yield
